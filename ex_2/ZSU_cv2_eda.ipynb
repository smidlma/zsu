# %% [markdown]
# # Exploratory data analysis
#
# Data source: https://www.kaggle.com/c/house-prices-advanced-regression-techniques/data
#
# Important attributes description:
# * SalePrice: The property's sale price in dollars. This is the target variable that you're trying to predict.
# * MSSubClass: The building class
# * BldgType: Type of dwelling
# * HouseStyle: Style of dwelling
# * OverallQual: Overall material and finish quality
# * OverallCond: Overall condition rating
# * YearBuilt: Original construction date
# * Heating: Type of heating
# * CentralAir: Central air conditioning
# * GrLivArea: Above grade (ground) living area square feet
# * BedroomAbvGr: Number of bedrooms above basement level

# %% [markdown]
# ## Import used packages

# %%
import pandas as pd # dataframes
import numpy as np # matrices and linear algebra
import matplotlib.pyplot as plt # plotting
import seaborn as sns # another matplotlib interface - styled and easier to use

# %% [markdown]
# ## Load the data into the Pandas DataFrame - in our case it is a csv file

# %%
df = pd.read_csv('../data/zsu_cv1_data.csv', sep=',')
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %% [markdown]
# ## Price is the most interisting attribute in our dataset, let's take a look on its distribution

# %% [markdown]
# #### Vizualize house prices in form of histogram
# - What does it tell us about the prices?

# %%
sns.displot(df.SalePrice)

# %% [markdown]
# #### Modify bins
# - Perhaps we want to visualize the histogram with more dense or coarse bins
# - *bins* attribute

# %%
sns.displot(df.SalePrice, bins=50)

# %% [markdown]
# #### Add probability density curve (Kernel density estimation)
#
# We can use parameter *kde* if we want to show estimation of probability density function.
#
# Modify colors of plot, use parameters:
# - *color*
# - *edgecolor*

# %%
sns.displot(df.SalePrice, bins=50, kde=True, color='blue', edgecolor='white')

# %% [markdown]
# #### Use quartiles (Q1, Q3) for highlighting most common price range in histogram
#
# Check functions *describe* and *quantile* over price column

# %%
df.SalePrice.describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
df.SalePrice.quantile(0.25), df.SalePrice.quantile(0.75)
# Out:
# (129975.0, 214000.0)

# %% [markdown]
# #### Use function *axvline* from Matplotlib to draw vertical lines at the quartile positions

# %%
fig = plt.figure(figsize=(9, 6))
sns.displot(df.SalePrice, bins=50, kde=True, color='blue', edgecolor='white')
plt.axvline(df.SalePrice.quantile(0.25), color='yellow')
plt.axvline(df.SalePrice.quantile(0.75), color='black')

# %% [markdown]
# ## Let's add more complexity to histogram vizualizations. Does price change for different values of GaragaFinish attribute?
#
# #### GarageFinish: Interior finish of the garage
# - Fin	Finished
# - RFn	Rough Finished
# - Unf	Unfinished
# - NA	No Garage

# %%
sns.displot(data=df, x='SalePrice', hue='GarageFinish', edgecolor='white')

# %% [markdown]
# ### We can see that houses with no garage are somehow missing
# - The no garage houses have a *nan* value in the feature so they are not plotted

# %%
df.GarageFinish = df.GarageFinish.fillna('NoGarage')

# %% [markdown]
# ### Sometimes the histograms distinguished by colors are not easily redeable
# - We can use *col* attribute to automatically plot every histogram on its own canvas

# %%
sns.displot(data=df, x='SalePrice', col='GarageFinish', edgecolor='white')

# %% [markdown]
# ## Cumulative distribution plot usage
# Task: I want to buy a house with live area of 150 m^2 maximum (1614 ft^2), how much choice do I have?
# - How to solve the task visually? We can make use of *ecdfplot*

# %%
sns.ecdfplot(df.GrLivArea)
plt.axvline(1614, color='black')

# %% [markdown]
# ### Moreover we may be interested in types of building so we can distinguish the houses by *BldgType* attribute
#
# #### BldgType: Type of dwelling
# - 1Fam	Single-family Detached
# - 2FmCon	Two-family Conversion; originally built as one-family dwelling
# - Duplx	Duplex
# - TwnhsE	Townhouse End Unit
# - TwnhsI	Townhouse Inside Unit
#
# https://housing.com/news/what-is-a-duplex-house/

# %%
sns.ecdfplot(data=df, x='GrLivArea', hue='BldgType')
plt.axvline(1614, color='black')

# %% [markdown]
# ### Zoom in using the *xlim* function

# %%
sns.ecdfplot(data=df, x='GrLivArea', hue='BldgType')
plt.axvline(1614, color='black')
plt.xlim(500, 3000)
# Out:
# (500.0, 3000.0)

# %% [markdown]
# ### Another very useful tecnique for the numerical features distributions are boxplots
# - Did you see any of these before?
# - How should we read them?
#     - Quartiles
#     - Median
#     - Box size
#     - Outliers and IQR
#     - Min/max - with or without outliers

# %% [markdown]
# ### Plot only the *SalePrice* using boxplot

# %%
sns.boxplot(y=df.SalePrice)
# Out:
# <AxesSubplot:ylabel='SalePrice'>

# %% [markdown]
# ## Let's take a look at the *SalePrice* for different *BldgType* values
# - What can we say about the prices?

# %%
fig = plt.figure(figsize=(16, 9))
sns.boxplot(data=df, y='SalePrice', x='BldgType')
# Out:
# <AxesSubplot:xlabel='BldgType', ylabel='SalePrice'>

# %% [markdown]
# ## We can do the same for *GrLivArea*

# %%
sns.boxplot(y=df.GrLivArea)
# Out:
# <AxesSubplot:ylabel='GrLivArea'>

# %% [markdown]
# ## Let's take a look at the *GrLivArea* for different *BldgType* values
# - What can we say about the GrLivArea?

# %%
fig = plt.figure(figsize=(16, 9))
sns.boxplot(data=df, y='GrLivArea', x='BldgType')
# Out:
# <AxesSubplot:xlabel='BldgType', ylabel='GrLivArea'>

# %% [markdown]
# ### We can use standard *scatterplot* with *BldgType* as a *hue* so we can better grasp the relationship between *GrLivArea* and *SalePrice*

# %%
fig = plt.figure(figsize=(16, 9))
sns.scatterplot(data=df, x='GrLivArea', y='SalePrice', hue='BldgType')
# Out:
# <AxesSubplot:xlabel='GrLivArea', ylabel='SalePrice'>

# %% [markdown]
# ### We can see there are some outliers in the data, let's zoom only to area without them, how can we filter the data?

# %%
fig = plt.figure(figsize=(16, 9))
sns.scatterplot(data=df[df.GrLivArea < 3000], x='GrLivArea', y='SalePrice', hue='BldgType')
# Out:
# <AxesSubplot:xlabel='GrLivArea', ylabel='SalePrice'>

# %% [markdown]
# ## We have an information about a month and a year for the sold houses.
# ### Can you vizualize what was the average price of the house by quarters?
#
# * We need to create a new columns with merged Year and Quarter information in this pattern: '2010-Q1','2010-Q2', etc.
# * We can map the values using the *apply* function or use string concatenation directly
# * If you need to change data type of the columns, you can use *astypy*

# %%
df['QuaterSold'] = df.MoSold // 4 + 1
df['YearQuaterSold'] = df.YrSold.astype(str) + '-' + df.QuaterSold.astype(str)
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... Fence MiscFeature MiscVal MoSold YrSold SaleType  \
# 0         Lvl    AllPub  ...   NaN         NaN       0      2   2008       WD
# 1         Lvl    AllPub  ...   NaN         NaN       0      5   2007       WD
# 2         Lvl    AllPub  ...   NaN         NaN       0      9   2008       WD
# 3         Lvl    AllPub  ...   NaN         NaN       0      2   2006       WD
# 4         Lvl    AllPub  ...   NaN         NaN       0     12   2008       WD
#
#   SaleCondition  SalePrice  QuaterSold  YearQuaterSold
# 0        Normal     208500           1          2008-1
# 1        Normal     181500           2          2007-2
# 2        Normal     223500           3          2008-3
# 3       Abnorml     140000           1          2006-1
# 4        Normal     250000           4          2008-4
#
# [5 rows x 83 columns]

# %%
df['YearQuarterSoldApply'] = df.loc[:, ['MoSold', 'YrSold']].apply(lambda x: f'{x[1]}-{(x[0]// 4 + 1)}',axis=1)
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... MiscFeature MiscVal MoSold YrSold SaleType  \
# 0         Lvl    AllPub  ...         NaN       0      2   2008       WD
# 1         Lvl    AllPub  ...         NaN       0      5   2007       WD
# 2         Lvl    AllPub  ...         NaN       0      9   2008       WD
# 3         Lvl    AllPub  ...         NaN       0      2   2006       WD
# 4         Lvl    AllPub  ...         NaN       0     12   2008       WD
#
#   SaleCondition SalePrice  QuaterSold  YearQuaterSold  YearQuarterSoldApply
# 0        Normal    208500           1          2008-1                2008-1
# 1        Normal    181500           2          2007-2                2007-2
# 2        Normal    223500           3          2008-3                2008-3
# 3       Abnorml    140000           1          2006-1                2006-1
# 4        Normal    250000           4          2008-4                2008-4
#
# [5 rows x 84 columns]

# %% [markdown]
# ### Compute the average price for the *YearQuarterSold* attribute

# %%
df_agg = df.groupby('YearQuaterSold').SalePrice.mean().reset_index(name='MeanPrice')
df_agg
# Out:
#    YearQuaterSold      MeanPrice
# 0          2006-1  190553.522727
# 1          2006-2  173835.900000
# 2          2006-3  197681.705128
# 3          2006-4  185545.000000
# 4          2007-1  178489.159091
# 5          2007-2  180689.732955
# 6          2007-3  194509.890110
# 7          2007-4  214414.500000
# 8          2008-1  173837.951220
# 9          2008-2  173830.396341
# 10         2008-3  186161.811765
# 11         2008-4  175600.000000
# 12         2009-1  180749.414634
# 13         2009-2  184147.612022
# 14         2009-3  172506.000000
# 15         2009-4  164014.533333
# 16         2010-1  185384.413043
# 17         2010-2  174544.263566

# %% [markdown]
# ## Vizualize the data using *lineplot*
# - In case of xlabels mixing try to tune the *rotation* and *horizontalalignment* parameters

# %%
sns.lineplot(data=df_agg, x='YearQuaterSold', y='MeanPrice')
plt.xticks(rotation=70)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Add the max, min and median to the plot
# - Use *describe* and the [Pandas Melt](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.melt.html) function
#     - use YearQuarterSold as an *id_vars*
#     - use 'min', 'mean', '50%', 'max' as *value_vars*

# %%
df_agg =df.groupby('YearQuaterSold').SalePrice.describe().reset_index()
df_agg
# Out:
#    YearQuaterSold  count           mean            std      min       25%  \
# 0          2006-1   44.0  190553.522727   71075.435079  52500.0  142875.0
# 1          2006-2  180.0  173835.900000   78147.648285  79000.0  129675.0
# 2          2006-3   78.0  197681.705128   86560.713023  35311.0  133625.0
# 3          2006-4   12.0  185545.000000   69292.448559  98600.0  132000.0
# 4          2007-1   44.0  178489.159091  119137.563987  39300.0  122000.0
# 5          2007-2  176.0  180689.732955   82447.813812  79000.0  129000.0
# 6          2007-3   91.0  194509.890110   72455.235610  64500.0  137500.0
# 7          2007-4   18.0  214414.500000   81118.090800  84500.0  144750.0
# 8          2008-1   41.0  173837.951220   73278.323817  55000.0  127000.0
# 9          2008-2  164.0  173830.396341   63180.075472  40000.0  135000.0
# 10         2008-3   85.0  186161.811765   82031.365706  67000.0  130500.0
# 11         2008-4   14.0  175600.000000   50868.019272  97000.0  141750.0
# 12         2009-1   41.0  180749.414634   93904.845325  60000.0  119500.0
# 13         2009-2  183.0  184147.612022   84246.205697  37900.0  132250.0
# 14         2009-3   99.0  172506.000000   70641.626988  34900.0  124450.0
# 15         2009-4   15.0  164014.533333   64650.008698  62383.0  111250.0
# 16         2010-1   46.0  185384.413043   90340.483327  88000.0  128050.0
# 17         2010-2  129.0  174544.263566   76798.813093  55000.0  129000.0
#
#          50%       75%       max
# 0   172700.0  228250.0  423000.0
# 1   157500.0  197725.0  625000.0
# 2   178000.0  244933.5  465000.0
# 3   175000.0  236000.0  290000.0
# 4   145450.0  200125.0  755000.0
# 5   156000.0  205787.5  745000.0
# 6   181000.0  238500.0  392000.0
# 7   231000.0  268975.0  340000.0
# 8   159895.0  192000.0  412500.0
# 9   165200.0  200450.0  385000.0
# 10  165500.0  223500.0  446261.0
# 11  169000.0  224500.0  250000.0
# 12  174000.0  219500.0  582933.0
# 13  162000.0  213625.0  555000.0
# 14  158000.0  202500.0  402861.0
# 15  162000.0  211000.0  263435.0
# 16  161875.0  213000.0  611657.0
# 17  154000.0  213000.0  538000.0

# %%
df_melt =pd.melt(df_agg, id_vars=['YearQuaterSold'], value_vars=['min', 'mean', '50%', 'max'])
df_melt
df_melt[df_melt.YearQuaterSold == '2006-1']
# Out:
#    YearQuaterSold variable          value
# 0          2006-1      min   52500.000000
# 18         2006-1     mean  190553.522727
# 36         2006-1      50%  172700.000000
# 54         2006-1      max  423000.000000

# %% [markdown]
# ## What can we say about the minimum and maximum values?
# - hint - std. deviation? outliers?

# %%
sns.lineplot(data=df_melt, x='YearQuaterSold', y='value', hue='variable')
plt.xticks(rotation=70)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # We can take a look at number of sold houses for the defined time periods as well
# - We will use standard bar plot
# - In which quarter were the most houses sold?
# - Fun facts: [https://themortgagereports.com/44135/whats-the-best-time-of-year-to-sell-a-home](https://themortgagereports.com/44135/whats-the-best-time-of-year-to-sell-a-home)

# %%
df_agg = df.groupby('YearQuaterSold').SalePrice.count().reset_index(name='count')
df_agg
# Out:
#    YearQuaterSold  count
# 0          2006-1     44
# 1          2006-2    180
# 2          2006-3     78
# 3          2006-4     12
# 4          2007-1     44
# 5          2007-2    176
# 6          2007-3     91
# 7          2007-4     18
# 8          2008-1     41
# 9          2008-2    164
# 10         2008-3     85
# 11         2008-4     14
# 12         2009-1     41
# 13         2009-2    183
# 14         2009-3     99
# 15         2009-4     15
# 16         2010-1     46
# 17         2010-2    129

# %%
sns.barplot(data=df_agg, x='YearQuaterSold', y='count')
plt.xticks(rotation=70)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Tasks

# %% [markdown]
# # Task 1 - Outlier detection (1p)
# - We need to somehow mark the outliers in the data according to the *SalePrice* and *GrLivArea*
#     - One possibility is to compute [IQR](https://www.statisticshowto.com/probability-and-statistics/interquartile-range/) for both columns and mark outliers using lower and upper bounds
#     - Lower bound: Q1 - 1.5*IQR
#     - Upper bound: Q3 + 1.5*IQR
# - If the house has *SalePrice* **OR** *GrLivArea* value outside of the bounds - it is an outlier
# - Vizualize the data using scatter plot and distinguish the outlier and non-outlier data using different colors (*hue*)

# %%
saleIQR = df.SalePrice.quantile(0.75) - df.SalePrice.quantile(0.25)
grLivAreaIQR = df.GrLivArea.quantile(0.75) - df.GrLivArea.quantile(0.25)
lbSale = df.SalePrice.quantile(0.25) - 1.5 * saleIQR
ubSale = df.SalePrice.quantile(0.75) + 1.5 * saleIQR
lbArea =  df.GrLivArea.quantile(0.25) - 1.5 * grLivAreaIQR
ubArea =  df.GrLivArea.quantile(0.75) + 1.5 * grLivAreaIQR

df['Outliners'] = False
df.loc[(df.SalePrice < lbSale) |( df.SalePrice > ubSale) | (df.GrLivArea < lbArea) | (df.GrLivArea > ubArea),'Outliners'] = True
sns.scatterplot(data=df, x=df.GrLivArea, y=df.SalePrice, hue=df.Outliners)
# Out:
# <AxesSubplot:xlabel='GrLivArea', ylabel='SalePrice'>

# %% [markdown]
# # Task 2 - Describe what you see in the data (1p)
# - Try to vizualize the relationship between *SalePrice* and *OverallQual*
#     - You can use BoxPlots, Scatter plots, etc.
# - Describe the insight you got from the plots with a few sentences
# - Do the same for *SalePrice* and *OverallCond*; i.e. vizualize and describe insight

# %%
sns.scatterplot(data=df, x='OverallQual', y='SalePrice')
sns.boxplot(data=df, x='OverallQual', y='SalePrice')
df_agg = df.groupby(df.OverallQual).SalePrice.count().reset_index(name='count')
df_agg
# Out:
#    OverallQual  count
# 0            1      2
# 1            2      3
# 2            3     20
# 3            4    116
# 4            5    397
# 5            6    374
# 6            7    319
# 7            8    168
# 8            9     43
# 9           10     18

# %%
# <!-- sns.scatterplot(data=df, x='OverallQual', y='SalePrice') -->
sns.boxplot(data=df, x='OverallCond', y='SalePrice')
df_agg = df.groupby(df.OverallCond).SalePrice.count().reset_index(name='count')
df_agg
# Out:
#    OverallCond  count
# 0            1      1
# 1            2      5
# 2            3     25
# 3            4     57
# 4            5    821
# 5            6    252
# 6            7    205
# 7            8     72
# 8            9     22
